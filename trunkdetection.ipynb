# %% [markdown]
# <a href="https://colab.research.google.com/github/divyachandana/tree-trunk-detection/blob/master/trunkdetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/divyachandana/objectDetectionKeras.git
# Out:
# Cloning into 'objectDetectionKeras'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 799 (delta 0), reused 1 (delta 0), pack-reused 796
# Receiving objects: 100% (799/799), 69.67 MiB | 30.67 MiB/s, done.
# Resolving deltas: 100% (372/372), done.

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-04-27 21:48:49--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   430KB/s    in 10m 23s
#
# 2020-04-27 21:59:15 (388 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !mv  yolov3.weights objectDetectionKeras/
# !cp /content/drive/My\ Drive/keras/yolov3.weights /content/objectDetectionKeras/

# %%
cd objectDetectionKeras/
# Out:
# /content/objectDetectionKeras

# %%
ls
# Out:
# coco_annotation.py   kmeans.py            train.py           yolo.py
# convert.py           LICENSE              train.txt          yolov3.cfg
# darknet53.cfg        model_data/          val.txt            yolov3-tiny.cfg
# data/                README.md            voc_annotation.py  yolo_video.py
# font/                test.txt             xml/
# generateImageSet.py  train_bottleneck.py  yolo3/

# %%
# !python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-04-28 01:05:24.558112: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 01:05:24.589552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python convert.py -w yolov3.cfg yolov3.weights model_data/yolo_weights.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-04-28 01:06:50.530481: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 01:06:50.543123: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python kmeans.py --annot_file project/train.txt --out_file project/custom_anchors.txt --num_clusters 9
# Out:
# K anchors:
#  [[ 20  72]
#  [ 25 111]
#  [ 32  85]
#  [ 35 131]
#  [ 42 196]
#  [ 52 119]
#  [ 59 277]
#  [ 63 169]
#  [108 239]]
# Accuracy: 78.75%

# %%
# !cp /content/drive/My\ Drive/darknet/darknet53.conv.74 /content/objectDetectionKeras/
# !ls
# !ls /content/drive/My\ Drive/darknet/
# Out:
# coco_annotation.py  generateImageSet.py  train_bottleneck.py  yolo3
# convert.py	    kmeans.py		 train.py	      yolo_anchors.txt
# darknet53.cfg	    LICENSE		 train.txt	      yolo.py
# darknet53.conv.74   model_data		 val.txt	      yolov3.cfg
# data		    README.md		 voc_annotation.py    yolov3-tiny.cfg
# font		    test.txt		 xml		      yolo_video.py
# backup	darknet		   img	     obj.names	train.txt
# cuDNN	darknet53.conv.74  obj.data  test.txt	yolov3.cfg

# %%
# !python convert.py -w darknet53.cfg darknet53.weights model_data/darknet53_weights.h5
# Out:
# Using TensorFlow backend.
# 2020-04-28 16:45:44.863885: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [0]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-04-28 16:45:46.478732: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 16:45:46.539121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 16:45:46.539751: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# ...

# %%
# !echo "from .load_backend import control_flow_ops from 
# .load_backend import set_image_dim_ordering $(cat /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py)" > /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py
# !echo "from .load_backend import control_flow_ops  $(cat /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py)" > /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py
# !echo "from .load_backend import set_image_dim_ordering $(cat /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py)" > /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py

# %%
# !pip install -q keras
# !cat /usr/local/lib/python3.6/dist-packages/keras/backend/__init__.py
# %cd '/usr/local/lib/python3.6/dist-packages/keras/backend'
# %%writefile __init__.py
# !cd 
# !cd /content/objectDetectionKeras/
# %cd '/content/objectDetectionKeras/'
# !pwd
# !ls
# Out:
# from .load_backend import epsilon
# from .load_backend import set_epsilon
# from .load_backend import floatx
# from .load_backend import set_floatx
# from .load_backend import cast_to_floatx
# from .load_backend import image_data_format
# from .load_backend import set_image_data_format
# from .load_backend import reset_uids
# from .load_backend import get_uid
# from .load_backend import learning_phase
# from .load_backend import set_learning_phase
# from .load_backend import is_sparse
# from .load_backend import to_dense
# from .load_backend import variable
# from .load_backend import is_variable
# from .load_backend import constant
# from .load_backend import is_keras_tensor
# from .load_backend import is_tensor
# from .load_backend import placeholder
# from .load_backend import is_placeholder
# from .load_backend import shape
# from .load_backend import int_shape
# from .load_backend import ndim
# from .load_backend import dtype
# from .load_backend import eval
# ...

# %%
# %cd '/usr/local/lib/python3.6/dist-packages/keras/backend'
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/backend

# %%
# %cd '/content/objectDetectionKeras/'
# Out:
# /content/objectDetectionKeras

# %%
# %%writefile __init__.py
from .load_backend import epsilon
from .load_backend import set_epsilon
from .load_backend import floatx
from .load_backend import set_floatx
from .load_backend import cast_to_floatx
from .load_backend import image_data_format
from .load_backend import set_image_data_format
from .load_backend import reset_uids
from .load_backend import get_uid
from .load_backend import learning_phase
from .load_backend import set_learning_phase
from .load_backend import is_sparse
from .load_backend import to_dense
from .load_backend import variable
from .load_backend import is_variable
from .load_backend import constant
from .load_backend import is_keras_tensor
from .load_backend import is_tensor
from .load_backend import placeholder
from .load_backend import is_placeholder
from .load_backend import shape
from .load_backend import int_shape
from .load_backend import ndim
from .load_backend import dtype
from .load_backend import eval
from .load_backend import zeros
from .load_backend import ones
from .load_backend import eye
from .load_backend import zeros_like
from .load_backend import ones_like
from .load_backend import identity
from .load_backend import random_uniform_variable
from .load_backend import random_normal_variable
from .load_backend import count_params
from .load_backend import cast
from .load_backend import update
from .load_backend import update_add
from .load_backend import update_sub
from .load_backend import moving_average_update
from .load_backend import dot
from .load_backend import batch_dot
from .load_backend import transpose
from .load_backend import gather
from .load_backend import max
from .load_backend import min
from .load_backend import sum
from .load_backend import prod
from .load_backend import cumsum
from .load_backend import cumprod
from .load_backend import var
from .load_backend import std
from .load_backend import mean
from .load_backend import any
from .load_backend import all
from .load_backend import argmax
from .load_backend import argmin
from .load_backend import square
from .load_backend import abs
from .load_backend import sqrt
from .load_backend import exp
from .load_backend import log
from .load_backend import logsumexp
from .load_backend import round
from .load_backend import sign
from .load_backend import pow
from .load_backend import clip
from .load_backend import equal
from .load_backend import not_equal
from .load_backend import greater
from .load_backend import greater_equal
from .load_backend import less
from .load_backend import less_equal
from .load_backend import maximum
from .load_backend import minimum
from .load_backend import sin
from .load_backend import cos
from .load_backend import normalize_batch_in_training
from .load_backend import batch_normalization
from .load_backend import concatenate
from .load_backend import reshape
from .load_backend import permute_dimensions
from .load_backend import resize_images
from .load_backend import resize_volumes
from .load_backend import repeat_elements
from .load_backend import repeat
from .load_backend import arange
from .load_backend import tile
from .load_backend import flatten
from .load_backend import batch_flatten
from .load_backend import expand_dims
from .load_backend import squeeze
from .load_backend import temporal_padding
from .load_backend import spatial_2d_padding
from .load_backend import spatial_3d_padding
from .load_backend import stack
from .load_backend import one_hot
from .load_backend import reverse
from .load_backend import slice
from .load_backend import get_value
from .load_backend import batch_get_value
from .load_backend import set_value
from .load_backend import batch_set_value
from .load_backend import print_tensor
from .load_backend import function
from .load_backend import gradients
from .load_backend import stop_gradient
from .load_backend import rnn
from .load_backend import switch
from .load_backend import in_train_phase
from .load_backend import in_test_phase
from .load_backend import relu
from .load_backend import elu
from .load_backend import softmax
from .load_backend import softplus
from .load_backend import softsign
from .load_backend import categorical_crossentropy
from .load_backend import sparse_categorical_crossentropy
from .load_backend import binary_crossentropy
from .load_backend import sigmoid
from .load_backend import hard_sigmoid
from .load_backend import tanh
from .load_backend import dropout
from .load_backend import l2_normalize
from .load_backend import in_top_k
from .load_backend import conv1d
from .load_backend import separable_conv1d
from .load_backend import conv2d
from .load_backend import separable_conv2d
from .load_backend import conv2d_transpose
from .load_backend import depthwise_conv2d
from .load_backend import conv3d
from .load_backend import conv3d_transpose
from .load_backend import pool2d
from .load_backend import pool3d
from .load_backend import bias_add
from .load_backend import random_normal
from .load_backend import random_uniform
from .load_backend import random_binomial
from .load_backend import truncated_normal
from .load_backend import ctc_label_dense_to_sparse
from .load_backend import ctc_batch_cost
from .load_backend import ctc_decode
from .load_backend import map_fn
from .load_backend import foldl
from .load_backend import foldr
from .load_backend import local_conv1d
from .load_backend import local_conv2d
from .load_backend import backend
from .load_backend import normalize_data_format
from .load_backend import name_scope
from .load_backend import symbolic
from .load_backend import eager
from .load_backend import size
from .load_backend import control_dependencies

if backend() == 'theano':
    from .load_backend import pattern_broadcast
elif backend() == 'tensorflow':
    from .load_backend import clear_session
    from .load_backend import manual_variable_initialization
    from .load_backend import get_session
    from .load_backend import set_session
    from tensorflow.python.ops import control_flow_ops
elif backend() == 'cntk':
    from .load_backend import clear_session
# Out:
# Overwriting __init__.py

# %%
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
# import keras
# print(keras.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
import tensorflow as tf
tf.python.control_flow_ops = tf

# %%
# !pip uninstall keras
# !pip install keras
# import keras

# %%
# !pip install tensorflow==2.1.5
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.1.5 (from versions: 0.12.1, 1.0.0, 1.0.1, 1.1.0rc0, 1.1.0rc1, 1.1.0rc2, 1.1.0, 1.2.0rc0, 1.2.0rc1, 1.2.0rc2, 1.2.0, 1.2.1, 1.3.0rc0, 1.3.0rc1, 1.3.0rc2, 1.3.0, 1.4.0rc0, 1.4.0rc1, 1.4.0, 1.4.1, 1.5.0rc0, 1.5.0rc1, 1.5.0, 1.5.1, 1.6.0rc0, 1.6.0rc1, 1.6.0, 1.7.0rc0, 1.7.0rc1, 1.7.0, 1.7.1, 1.8.0rc0, 1.8.0rc1, 1.8.0, 1.9.0rc0, 1.9.0rc1, 1.9.0rc2, 1.9.0, 1.10.0rc0, 1.10.0rc1, 1.10.0, 1.10.1, 1.11.0rc0, 1.11.0rc1, 1.11.0rc2, 1.11.0, 1.12.0rc0, 1.12.0rc1, 1.12.0rc2, 1.12.0, 1.12.2, 1.12.3, 1.13.0rc0, 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 1.15.2, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0, 2.0.1, 2.1.0rc0, 2.1.0rc1, 2.1.0rc2, 2.1.0, 2.2.0rc0, 2.2.0rc1, 2.2.0rc2, 2.2.0rc3)
# ERROR: No matching distribution found for tensorflow==2.1.5

# %%
# !python train.py
# Out:
# Using TensorFlow backend.
# 2020-04-28 17:32:03.249833: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ['trunk']
# 9
# 2020-04-28 17:32:04.803273: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 17:32:04.824841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 17:32:04.825445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-28 17:32:04.825482: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !cp /content/objectDetectionKeras/logs/000/trained_weights_final.h5 /content/drive/My\ Drive/keras
# !cp /content/objectDetectionKeras/logs/000/trained_weights_stage_1.h5 /content/drive/My\ Drive/keras

# %%
# !cp -r /content/drive/My\ Drive/dataYoloV3/images /content/objectDetectionKeras/data/VOC/

# %%
# !cp /content/objectDetectionKeras/logs/000/trained_weights_final.h5 /content/objectDetectionKeras/model_data/
# !cp /content/objectDetectionKeras/logs/000/trained_weights_stage_1.h5 /content/objectDetectionKeras/model_data/

# %%
# !python yolo_RS.py
# Out:
# Using TensorFlow backend.
# 2020-04-28 20:30:45.118412: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 20:30:45.120512: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-04-28 20:30:45.120556: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: d78c09af7ed9
# 2020-04-28 20:30:45.120571: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: d78c09af7ed9
# 2020-04-28 20:30:45.120639: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 418.67.0
# 2020-04-28 20:30:45.120671: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 418.67.0
# 2020-04-28 20:30:45.120685: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 418.67.0
# ...

# %%
# !cp -r /content/drive/My\ Drive/keras/images /content/objectDetectionKeras/
